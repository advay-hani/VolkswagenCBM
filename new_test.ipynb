# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima  # For automated ARIMA tuning
import warnings
warnings.filterwarnings("ignore")


# File path
csv_path = r"D:\Github\HeavyVehicleCBM\dataset.csv"  # Replace with the correct path to your CSV file

# Define thresholds for each parameter
thresholds = {
    'vibr_1_X': 27.9,
    'vibr_1_Y': 27.9,
    'vibr_1_Z': 27.9,
    'vibr_1_noise': 99.2,
    'vibr_2_X': 27.9,
    'vibr_2_Y': 27.9,
    'vibr_2_Z': 27.9,
    'vibr_2_noise': 107.3,
    'oil_temp': 100,
    'cool_temp': 104,
    'oil_pressure': 100,
    'total_rms_vibr': 50,
    'total_rms_noise': 50,
}

# Define maintenance actions
maintenance_actions = {
    'vibr_1_X': "Check and replace vibration dampeners.",
    'vibr_1_Y': "Inspect the foundation and tighten bolts.",
    'vibr_1_Z': "Lubricate motor and inspect bearings.",
    'vibr_1_noise': "Inspect for excessive noise or damage.",
    'vibr_2_X': "Check and replace vibration dampeners.",
    'vibr_2_Y': "Inspect the foundation and tighten bolts.",
    'vibr_2_Z': "Lubricate motor and inspect bearings.",
    'vibr_2_noise': "Inspect for excessive noise or damage.",
    'oil_temp': "Inspect oil cooling system.",
    'cool_temp': "Inspect cooling system and replace coolant.",
    'oil_pressure': "Inspect oil pressure system.",
    'total_rms_vibr': "Inspect vibration dampeners and the system foundation.",
    'total_rms_noise': "Check for loose components or wear in mechanical parts."
}

# Load the CSV
df = pd.read_csv(csv_path)

# Convert timestamp column to datetime if it exists
if 'timestamp' in df.columns:
    df['timestamp'] = pd.to_datetime(df['timestamp'])
    df.set_index('timestamp', inplace=True)

# Ensure numeric values
df = df.apply(pd.to_numeric, errors='coerce')

# Maintenance actions tracking
maintenance_needed = {}

# Process each parameter
for column in thresholds.keys():
    if column in df.columns:
        print(f"Processing: {column}")

        # ACF/PACF Analysis
        print(f"Generating ACF/PACF plots for {column}...")
        plt.figure(figsize=(12, 5))
        plt.subplot(1, 2, 1)
        plot_acf(df[column].dropna(), ax=plt.gca(), lags=40)
        plt.title(f"ACF for {column}")

        plt.subplot(1, 2, 2)
        plot_pacf(df[column].dropna(), ax=plt.gca(), lags=40)
        plt.title(f"PACF for {column}")
        plt.tight_layout()
        plt.show()

        # Automated ARIMA selection
        print(f"Tuning ARIMA parameters for {column}...")
        try:
            model_auto = auto_arima(df[column].dropna(), seasonal=False, trace=True, error_action='ignore', suppress_warnings=True)
            print(model_auto.summary())

            # Forecast
            model = ARIMA(df[column].dropna(), order=model_auto.order).fit()
            forecast = model.predict(start=len(df), end=len(df) + 30 * 24, dynamic=True)
            future_dates = pd.date_range(start=df.index[-1], periods=len(forecast), freq='H')

            # Check threshold violations
            if np.any(forecast > thresholds[column]):
                maintenance_needed[column] = maintenance_actions[column]

            # Plot historical data and forecast
            plt.figure(figsize=(10, 6))
            plt.plot(df[column], label='Historical Data', color='blue')
            plt.plot(future_dates, forecast, label='Forecast', color='green', linestyle='dashed')
            plt.axhline(y=thresholds[column], color='red', linestyle='dotted', label='Threshold')
            plt.title(f"{column} Analysis")
            plt.xlabel("Time")
            plt.ylabel("Value")
            plt.legend()
            plt.grid()
            plt.show()

        except Exception as e:
            print(f"Error processing column {column}: {e}")

# Display maintenance actions
if maintenance_needed:
    print("Maintenance required for the following parameters:")
    for param, action in maintenance_needed.items():
        print(f"{param}: {action}")
else:
    print("No maintenance required.")
# Out:
# Processing: vibr_1_X
# Generating ACF/PACF plots for vibr_1_X...
# Tuning ARIMA parameters for vibr_1_X...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3691.624, Time=0.60 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3741.502, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3737.350, Time=0.12 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3731.980, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3739.544, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3690.165, Time=0.37 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=3690.191, Time=0.20 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3714.791, Time=0.36 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=3691.546, Time=0.67 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=3689.794, Time=0.26 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=3691.580, Time=0.33 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=3693.041, Time=1.08 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=3687.872, Time=0.15 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=3688.277, Time=0.18 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=3689.621, Time=0.36 sec
#  ARIMA(0,1,4)(0,0,0)[0]             : AIC=3689.657, Time=0.20 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=3688.245, Time=0.19 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=3691.118, Time=0.58 sec
#
# Best model:  ARIMA(0,1,3)(0,0,0)[0]
# Total fit time: 5.880 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(0, 1, 3)   Log Likelihood               -1839.936
# Date:                Sun, 17 Nov 2024   AIC                           3687.872
# Time:                        01:55:42   BIC                           3706.748
# Sample:                    07-23-2024   HQIC                          3695.112
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.1067      0.014     -7.478      0.000      -0.135      -0.079
# ma.L2         -0.2375      0.021    -11.250      0.000      -0.279      -0.196
# ma.L3          0.0531      0.027      1.946      0.052      -0.000       0.107
# sigma2         4.9840      0.059     84.216      0.000       4.868       5.100
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             39043.56
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.85   Skew:                            -1.72
# Prob(H) (two-sided):                  0.00   Kurtosis:                        36.47
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing: vibr_1_Y
# Generating ACF/PACF plots for vibr_1_Y...
# Tuning ARIMA parameters for vibr_1_Y...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3692.807, Time=0.70 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3745.329, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3747.282, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3747.232, Time=0.15 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3743.444, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3691.072, Time=0.68 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=3689.086, Time=0.20 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=3691.074, Time=0.27 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3723.804, Time=0.49 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=2.13 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=3687.298, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=3745.351, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=3689.282, Time=0.24 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=3689.284, Time=0.15 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=3722.223, Time=0.23 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=inf, Time=1.52 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0]
# Total fit time: 7.149 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(0, 1, 2)   Log Likelihood               -1840.649
# Date:                Sun, 17 Nov 2024   AIC                           3687.298
# Time:                        01:55:51   BIC                           3701.455
# Sample:                    07-23-2024   HQIC                          3692.728
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.0128      0.016     -0.811      0.418      -0.044       0.018
# ma.L2         -0.2783      0.023    -12.104      0.000      -0.323      -0.233
# sigma2         4.9924      0.066     75.120      0.000       4.862       5.123
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             25197.45
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.09   Skew:                            -0.68
# Prob(H) (two-sided):                  0.48   Kurtosis:                        29.99
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing: vibr_1_Z
# Generating ACF/PACF plots for vibr_1_Z...
# Tuning ARIMA parameters for vibr_1_Z...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3902.843, Time=0.52 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3967.365, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3957.740, Time=0.12 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3947.657, Time=0.15 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3965.410, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3901.397, Time=0.38 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=3900.362, Time=0.21 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=3901.634, Time=0.33 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3919.974, Time=0.37 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=3903.170, Time=0.70 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=3898.476, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=3945.729, Time=0.08 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=3899.505, Time=0.22 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=3899.743, Time=0.16 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=3918.101, Time=0.17 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=3901.279, Time=0.36 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0]
# Total fit time: 3.966 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(0, 1, 2)   Log Likelihood               -1946.238
# Date:                Sun, 17 Nov 2024   AIC                           3898.476
# Time:                        01:55:56   BIC                           3912.633
# Sample:                    07-23-2024   HQIC                          3903.906
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.1514      0.016     -9.647      0.000      -0.182      -0.121
# ma.L2         -0.2593      0.017    -14.832      0.000      -0.294      -0.225
# sigma2         6.4428      0.081     79.590      0.000       6.284       6.601
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):             36659.01
# Prob(Q):                              0.81   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.57   Skew:                            -1.90
# Prob(H) (two-sided):                  0.00   Kurtosis:                        35.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing: vibr_1_noise
# Generating ACF/PACF plots for vibr_1_noise...
# Tuning ARIMA parameters for vibr_1_noise...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3480.851, Time=1.06 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3941.310, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3708.718, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3477.435, Time=0.36 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3939.311, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3479.433, Time=0.32 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=3479.434, Time=0.36 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3479.772, Time=0.75 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=3475.455, Time=0.10 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=3477.453, Time=0.14 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=3477.453, Time=0.14 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=3706.721, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=3477.791, Time=0.31 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 3.804 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(0, 1, 1)   Log Likelihood               -1735.727
# Date:                Sun, 17 Nov 2024   AIC                           3475.455
# Time:                        01:56:01   BIC                           3484.893
# Sample:                    07-23-2024   HQIC                          3479.075
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8719      0.015    -57.364      0.000      -0.902      -0.842
# sigma2         3.8689      0.035    111.795      0.000       3.801       3.937
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            121460.05
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.66   Skew:                            -4.93
# Prob(H) (two-sided):                  0.00   Kurtosis:                        61.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing: vibr_2_X
# Generating ACF/PACF plots for vibr_2_X...
# Tuning ARIMA parameters for vibr_2_X...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3070.948, Time=0.95 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3084.139, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3085.498, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3085.514, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3082.208, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3078.761, Time=0.57 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=3080.258, Time=0.83 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=3065.262, Time=1.02 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=3063.419, Time=0.55 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=3068.604, Time=0.26 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=3065.371, Time=0.88 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=3087.443, Time=0.16 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=3066.989, Time=0.27 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=3063.369, Time=1.87 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=3064.651, Time=1.81 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=3064.856, Time=2.46 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=3063.410, Time=1.63 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=3064.017, Time=1.56 sec
#  ARIMA(5,1,3)(0,0,0)[0] intercept   : AIC=3066.677, Time=1.52 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=3061.504, Time=1.10 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=3063.396, Time=0.60 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=3063.502, Time=0.50 sec
#  ARIMA(5,1,2)(0,0,0)[0]             : AIC=3062.780, Time=1.22 sec
#  ARIMA(4,1,3)(0,0,0)[0]             : AIC=3062.986, Time=1.51 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=3061.549, Time=0.33 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=3061.536, Time=0.75 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : AIC=3062.129, Time=0.78 sec
#  ARIMA(5,1,3)(0,0,0)[0]             : AIC=3064.643, Time=2.11 sec
#
# Best model:  ARIMA(4,1,2)(0,0,0)[0]
# Total fit time: 25.618 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(4, 1, 2)   Log Likelihood               -1523.752
# Date:                Sun, 17 Nov 2024   AIC                           3061.504
# Time:                        01:56:28   BIC                           3094.537
# Sample:                    07-23-2024   HQIC                          3074.173
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2933      0.255     -1.152      0.249      -0.792       0.206
# ar.L2          0.5363      0.132      4.053      0.000       0.277       0.796
# ar.L3         -0.1744      0.028     -6.312      0.000      -0.229      -0.120
# ar.L4         -0.1054      0.068     -1.554      0.120      -0.238       0.028
# ma.L1          0.3121      0.254      1.230      0.219      -0.185       0.809
# ma.L2         -0.5340      0.123     -4.344      0.000      -0.775      -0.293
# sigma2         2.3222      0.016    144.239      0.000       2.291       2.354
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            617692.61
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.34   Skew:                             3.09
# Prob(H) (two-sided):                  0.01   Kurtosis:                       136.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing: vibr_2_Y
# Generating ACF/PACF plots for vibr_2_Y...
# Tuning ARIMA parameters for vibr_2_Y...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2933.715, Time=0.95 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2964.824, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2963.917, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2963.932, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2962.858, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=2946.781, Time=0.66 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=2942.571, Time=0.85 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=2930.208, Time=1.10 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=2928.514, Time=0.70 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=2947.060, Time=0.21 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=2930.192, Time=0.77 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=2965.865, Time=0.17 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=2936.300, Time=0.27 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=2932.190, Time=1.48 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=2926.596, Time=0.36 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=2940.658, Time=0.42 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=2945.102, Time=0.14 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=2928.271, Time=0.44 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=2928.287, Time=0.47 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=2963.895, Time=0.08 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=2931.790, Time=0.46 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=2934.354, Time=0.15 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=2930.269, Time=0.71 sec
#
# Best model:  ARIMA(3,1,1)(0,0,0)[0]
# Total fit time: 10.749 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(3, 1, 1)   Log Likelihood               -1458.298
# Date:                Sun, 17 Nov 2024   AIC                           2926.596
# Time:                        01:56:42   BIC                           2950.191
# Sample:                    07-23-2024   HQIC                          2935.645
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7007      0.081      8.608      0.000       0.541       0.860
# ar.L2         -0.0363      0.061     -0.595      0.552      -0.156       0.083
# ar.L3         -0.1605      0.043     -3.734      0.000      -0.245      -0.076
# ma.L1         -0.6753      0.082     -8.209      0.000      -0.837      -0.514
# sigma2         1.9825      0.017    113.881      0.000       1.948       2.017
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            246136.69
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.95   Skew:                             1.96
# Prob(H) (two-sided):                  0.00   Kurtosis:                        87.37
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing: vibr_2_Z
# Generating ACF/PACF plots for vibr_2_Z...
# Tuning ARIMA parameters for vibr_2_Z...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3465.388, Time=0.94 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3488.169, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3487.408, Time=0.13 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3487.510, Time=0.15 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3486.181, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3475.127, Time=0.59 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=3485.605, Time=0.66 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=3457.100, Time=0.84 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=3455.997, Time=0.62 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=3463.881, Time=0.24 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=3457.048, Time=0.97 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=3489.357, Time=0.18 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=3461.174, Time=0.29 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=3459.034, Time=1.94 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=3454.030, Time=0.35 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=3483.616, Time=0.39 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=3461.899, Time=0.14 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=3455.084, Time=0.54 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=3455.135, Time=0.48 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=3487.368, Time=0.08 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=3463.420, Time=0.49 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=3459.196, Time=0.18 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=3457.069, Time=1.05 sec
#
# Best model:  ARIMA(3,1,1)(0,0,0)[0]
# Total fit time: 11.356 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(3, 1, 1)   Log Likelihood               -1722.015
# Date:                Sun, 17 Nov 2024   AIC                           3454.030
# Time:                        01:56:55   BIC                           3477.625
# Sample:                    07-23-2024   HQIC                          3463.079
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6427      0.087      7.384      0.000       0.472       0.813
# ar.L2         -0.0159      0.062     -0.257      0.797      -0.137       0.106
# ar.L3         -0.1727      0.040     -4.306      0.000      -0.251      -0.094
# ma.L1         -0.6113      0.089     -6.902      0.000      -0.785      -0.438
# sigma2         3.7486      0.029    128.739      0.000       3.692       3.806
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):            507316.21
# Prob(Q):                              0.92   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.09   Skew:                            -1.93
# Prob(H) (two-sided):                  0.00   Kurtosis:                       124.20
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing: vibr_2_noise
# Generating ACF/PACF plots for vibr_2_noise...
# Tuning ARIMA parameters for vibr_2_noise...
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.72 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=10030.703, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=8925.243, Time=0.37 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.70 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=7956.763, Time=1.17 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.94 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=7264.976, Time=0.79 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=3104.755, Time=0.34 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=1.14 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=3095.756, Time=1.36 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=inf, Time=1.18 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=3.00 sec
#  ARIMA(1,0,5)(0,0,0)[0]             : AIC=3095.043, Time=1.86 sec
#  ARIMA(0,0,5)(0,0,0)[0]             : AIC=inf, Time=2.15 sec
#  ARIMA(2,0,5)(0,0,0)[0]             : AIC=3093.249, Time=3.00 sec
#  ARIMA(3,0,5)(0,0,0)[0]             : AIC=inf, Time=3.41 sec
#  ARIMA(3,0,4)(0,0,0)[0]             : AIC=inf, Time=2.45 sec
#  ARIMA(2,0,5)(0,0,0)[0] intercept   : AIC=3080.261, Time=8.57 sec
#  ARIMA(1,0,5)(0,0,0)[0] intercept   : AIC=3079.048, Time=0.81 sec
#  ARIMA(0,0,5)(0,0,0)[0] intercept   : AIC=3077.031, Time=0.36 sec
#  ARIMA(0,0,4)(0,0,0)[0] intercept   : AIC=3075.103, Time=0.29 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=3075.664, Time=0.24 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=3077.050, Time=0.97 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=3077.745, Time=0.38 sec
#
# Best model:  ARIMA(0,0,4)(0,0,0)[0] intercept
# Total fit time: 36.314 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(0, 0, 4)   Log Likelihood               -1531.552
# Date:                Sun, 17 Nov 2024   AIC                           3075.103
# Time:                        01:57:33   BIC                           3103.425
# Sample:                    07-23-2024   HQIC                          3085.965
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    102.4752      0.064   1613.471      0.000     102.351     102.600
# ma.L1         -0.0295      0.036     -0.815      0.415      -0.100       0.041
# ma.L2         -0.0174      0.035     -0.491      0.624      -0.087       0.052
# ma.L3          0.0047      0.038      0.122      0.903      -0.070       0.079
# ma.L4          0.0519      0.033      1.587      0.113      -0.012       0.116
# sigma2         2.3563      0.104     22.601      0.000       2.152       2.561
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               190.88
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.92   Skew:                            -0.94
# Prob(H) (two-sided):                  0.46   Kurtosis:                         4.42
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing: oil_temp
# Generating ACF/PACF plots for oil_temp...
# Tuning ARIMA parameters for oil_temp...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=592.670, Time=0.35 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=584.701, Time=0.24 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=586.694, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=586.694, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=582.714, Time=0.10 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=588.694, Time=0.26 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 1.255 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                -290.357
# Date:                Sun, 17 Nov 2024   AIC                            582.714
# Time:                        01:57:36   BIC                            587.433
# Sample:                    07-23-2024   HQIC                           584.524
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         0.1181      0.001    211.081      0.000       0.117       0.119
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):           1584847.82
# Prob(Q):                              0.93   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.52   Skew:                           -11.66
# Prob(H) (two-sided):                  0.00   Kurtosis:                       216.06
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing: cool_temp
# Generating ACF/PACF plots for cool_temp...
# Tuning ARIMA parameters for cool_temp...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=4056.307, Time=0.83 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=4070.078, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=4058.404, Time=0.13 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=4057.522, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=4068.078, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=4058.105, Time=0.70 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=4060.020, Time=0.45 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=4045.945, Time=1.15 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=4046.772, Time=0.62 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=4047.474, Time=1.73 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=4047.904, Time=1.65 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=4047.524, Time=1.16 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=4045.513, Time=0.65 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=4043.990, Time=0.26 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=4048.843, Time=0.25 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=4045.436, Time=0.47 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=4047.100, Time=2.10 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=4041.990, Time=0.16 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=4046.844, Time=0.14 sec
#  ARIMA(5,1,0)(0,0,0)[0]             : AIC=4043.436, Time=0.21 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=4043.513, Time=0.40 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=4044.772, Time=0.34 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : AIC=4045.100, Time=0.96 sec
#
# Best model:  ARIMA(4,1,0)(0,0,0)[0]
# Total fit time: 14.601 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(4, 1, 0)   Log Likelihood               -2015.995
# Date:                Sun, 17 Nov 2024   AIC                           4041.990
# Time:                        01:57:52   BIC                           4065.585
# Sample:                    07-23-2024   HQIC                          4051.039
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1226      0.025     -4.993      0.000      -0.171      -0.074
# ar.L2         -0.0367      0.077     -0.475      0.635      -0.188       0.115
# ar.L3         -0.1129      0.011    -10.198      0.000      -0.135      -0.091
# ar.L4          0.0906      0.018      5.071      0.000       0.056       0.126
# sigma2         7.6260      0.045    171.181      0.000       7.539       7.713
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):            885315.33
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.38   Skew:                           -10.91
# Prob(H) (two-sided):                  0.01   Kurtosis:                       161.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing: oil_pressure
# Generating ACF/PACF plots for oil_pressure...
# Tuning ARIMA parameters for oil_pressure...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=830.598, Time=1.10 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=931.409, Time=0.16 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=833.035, Time=0.17 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=827.214, Time=0.26 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=929.773, Time=0.12 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=828.712, Time=0.33 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=828.833, Time=0.34 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=829.613, Time=0.64 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=826.227, Time=0.11 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=827.670, Time=0.18 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=827.801, Time=0.14 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=831.770, Time=0.08 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=828.573, Time=0.39 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 4.045 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                -411.113
# Date:                Sun, 17 Nov 2024   AIC                            826.227
# Time:                        01:57:57   BIC                            835.665
# Sample:                    07-23-2024   HQIC                           829.846
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.3602      0.008    -46.023      0.000      -0.376      -0.345
# sigma2         0.1580      0.001    143.489      0.000       0.156       0.160
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.09   Jarque-Bera (JB):            346355.66
# Prob(Q):                              0.77   Prob(JB):                         0.00
# Heteroskedasticity (H):              10.29   Skew:                            -0.85
# Prob(H) (two-sided):                  0.00   Kurtosis:                       103.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing: total_rms_vibr
# Generating ACF/PACF plots for total_rms_vibr...
# Tuning ARIMA parameters for total_rms_vibr...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3856.583, Time=1.66 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=4161.502, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3990.099, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3853.621, Time=0.19 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=4159.507, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3854.330, Time=0.30 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=3854.215, Time=0.28 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3855.736, Time=0.53 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=3851.649, Time=0.08 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=3852.362, Time=0.13 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=3852.246, Time=0.12 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=3988.113, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=3853.766, Time=0.31 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 3.873 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(0, 1, 1)   Log Likelihood               -1923.825
# Date:                Sun, 17 Nov 2024   AIC                           3851.649
# Time:                        01:58:03   BIC                           3861.087
# Sample:                    07-23-2024   HQIC                          3855.269
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.7038      0.016    -43.303      0.000      -0.736      -0.672
# sigma2         6.0995      0.097     62.778      0.000       5.909       6.290
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.79   Jarque-Bera (JB):             11201.78
# Prob(Q):                              0.37   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.76   Skew:                            -2.90
# Prob(H) (two-sided):                  0.02   Kurtosis:                        20.06
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing: total_rms_noise
# Generating ACF/PACF plots for total_rms_noise...
# Tuning ARIMA parameters for total_rms_noise...
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.91 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=9984.072, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=8905.037, Time=0.29 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.71 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=8067.639, Time=0.45 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=1.67 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=7454.968, Time=1.30 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=inf, Time=2.01 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=7026.548, Time=2.42 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=4382.253, Time=1.62 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=2.10 sec
#  ARIMA(1,0,5)(0,0,0)[0]             : AIC=4383.966, Time=0.66 sec
#  ARIMA(0,0,5)(0,0,0)[0]             : AIC=inf, Time=2.64 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=2.03 sec
#  ARIMA(2,0,5)(0,0,0)[0]             : AIC=inf, Time=3.17 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=4365.359, Time=2.01 sec
#  ARIMA(0,0,4)(0,0,0)[0] intercept   : AIC=4364.330, Time=0.50 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=4362.661, Time=0.43 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=4365.510, Time=0.28 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=4363.523, Time=0.56 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=4365.919, Time=0.96 sec
#
# Best model:  ARIMA(0,0,3)(0,0,0)[0] intercept
# Total fit time: 26.795 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(0, 0, 3)   Log Likelihood               -2176.331
# Date:                Sun, 17 Nov 2024   AIC                           4362.661
# Time:                        01:58:31   BIC                           4386.262
# Sample:                    07-23-2024   HQIC                          4371.712
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     99.5872      0.378    263.145      0.000      98.845     100.329
# ma.L1          0.0789      0.033      2.388      0.017       0.014       0.144
# ma.L2          0.0353      0.038      0.919      0.358      -0.040       0.110
# ma.L3          0.0738      0.031      2.374      0.018       0.013       0.135
# sigma2        11.1627      0.632     17.660      0.000       9.924      12.402
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              4349.66
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.91   Skew:                            -3.13
# Prob(H) (two-sided):                  0.41   Kurtosis:                        12.32
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Maintenance required for the following parameters:
# vibr_1_X: Check and replace vibration dampeners.
# vibr_1_Y: Inspect the foundation and tighten bolts.
# vibr_1_Z: Lubricate motor and inspect bearings.
# total_rms_noise: Check for loose components or wear in mechanical parts.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima
import warnings
warnings.filterwarnings("ignore")

# File path
csv_path = r"D:\Github\HeavyVehicleCBM\dataset.csv"

# Define thresholds for each parameter
thresholds = {
    'vibr_1_X': 27.9,
    'vibr_1_Y': 27.9,
    'vibr_1_Z': 27.9,
    'vibr_1_noise': 99.2,
    'vibr_2_X': 27.9,
    'vibr_2_Y': 27.9,
    'vibr_2_Z': 27.9,
    'vibr_2_noise': 107.3,
    'oil_temp': 100,
    'cool_temp': 104,
    'oil_pressure': 100,
    'total_rms_vibr': 50,
    'total_rms_noise': 50,
}

# Define maintenance actions
maintenance_actions = {
    'vibr_1_X': "Check and replace vibration dampeners.",
    'vibr_1_Y': "Inspect the foundation and tighten bolts.",
    'vibr_1_Z': "Lubricate motor and inspect bearings.",
    'vibr_1_noise': "Inspect for excessive noise or damage.",
    'vibr_2_X': "Check and replace vibration dampeners.",
    'vibr_2_Y': "Inspect the foundation and tighten bolts.",
    'vibr_2_Z': "Lubricate motor and inspect bearings.",
    'vibr_2_noise': "Inspect for excessive noise or damage.",
    'oil_temp': "Inspect oil cooling system.",
    'cool_temp': "Inspect cooling system and replace coolant.",
    'oil_pressure': "Inspect oil pressure system.",
    'total_rms_vibr': "Inspect vibration dampeners and the system foundation.",
    'total_rms_noise': "Check for loose components or wear in mechanical parts."
}

# Load the CSV
df = pd.read_csv(csv_path)

# Convert timestamp column to datetime if it exists
if 'timestamp' in df.columns:
    df['timestamp'] = pd.to_datetime(df['timestamp'])
    df.set_index('timestamp', inplace=True)

# Fill missing values (e.g., using forward fill or interpolation)
df = df.apply(pd.to_numeric, errors='coerce').fillna(method='ffill')

# Resample the data hourly if needed
df = df.resample('H').mean()

# Maintenance actions tracking
maintenance_needed = {}

# Process each parameter
for column in thresholds.keys():
    if column in df.columns:
        print(f"\nProcessing: {column}")

        # ACF/PACF Analysis
        plt.figure(figsize=(12, 5))
        plt.subplot(1, 2, 1)
        plot_acf(df[column].dropna(), ax=plt.gca(), lags=40)
        plt.title(f"ACF for {column}")

        plt.subplot(1, 2, 2)
        plot_pacf(df[column].dropna(), ax=plt.gca(), lags=40)
        plt.title(f"PACF for {column}")
        plt.tight_layout()
        plt.show()

        # Automated ARIMA selection
        try:
            print(f"Tuning ARIMA parameters for {column}...")
            model_auto = auto_arima(
                df[column].dropna(), seasonal=False, trace=True, 
                error_action='ignore', suppress_warnings=True
            )
            print(model_auto.summary())

            # Build ARIMA model and forecast
            model = ARIMA(df[column].dropna(), order=model_auto.order).fit()
            forecast_steps = 30 * 24  # Forecasting for next 30 days with hourly steps
            forecast = model.predict(start=len(df), end=len(df) + forecast_steps - 1, dynamic=True)
            future_dates = pd.date_range(start=df.index[-1], periods=forecast_steps, freq='H')

            # Detect threshold violations
            over_threshold = forecast > thresholds[column]
            if np.any(over_threshold):
                maintenance_needed[column] = maintenance_actions[column]
                over_threshold_dates = future_dates[over_threshold]

                print(f"Threshold exceeded for {column} at {over_threshold_dates[0]}")

            # Plot historical data and forecast
            plt.figure(figsize=(10, 6))
            plt.plot(df[column], label='Historical Data', color='blue')
            plt.plot(future_dates, forecast, label='Forecast', color='green', linestyle='dashed')
            plt.axhline(y=thresholds[column], color='red', linestyle='dotted', label='Threshold')
            plt.title(f"{column} Analysis")
            plt.xlabel("Time")
            plt.ylabel("Value")
            plt.legend()
            plt.grid()

            # Annotate exceedances
            if np.any(over_threshold):
                plt.annotate(
                    'Threshold Exceeded', 
                    xy=(over_threshold_dates[0], forecast[over_threshold][0]),
                    xytext=(over_threshold_dates[0], forecast[over_threshold][0] + 10),
                    arrowprops=dict(facecolor='red', shrink=0.05),
                    fontsize=10, color='red'
                )
            plt.show()

        except Exception as e:
            print(f"Error processing column {column}: {e}")

# Display maintenance actions
if maintenance_needed:
    print("\nMaintenance required for the following parameters:")
    for param, action in maintenance_needed.items():
        print(f"{param}: {action}")
else:
    print("\nNo maintenance required.")
# Out:
# Processing: vibr_1_X
# Tuning ARIMA parameters for vibr_1_X...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3691.624, Time=0.62 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3741.502, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3737.350, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3731.980, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3739.544, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3690.165, Time=0.40 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=3690.191, Time=0.17 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3714.791, Time=0.36 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=3691.546, Time=0.68 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=3689.794, Time=0.27 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=3691.580, Time=0.33 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=3693.041, Time=1.06 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=3687.872, Time=0.16 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=3688.277, Time=0.17 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=3689.621, Time=0.38 sec
#  ARIMA(0,1,4)(0,0,0)[0]             : AIC=3689.657, Time=0.20 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=3688.245, Time=0.20 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=3691.118, Time=0.60 sec
#
# Best model:  ARIMA(0,1,3)(0,0,0)[0]
# Total fit time: 5.992 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(0, 1, 3)   Log Likelihood               -1839.936
# Date:                Sun, 17 Nov 2024   AIC                           3687.872
# Time:                        12:57:09   BIC                           3706.748
# Sample:                    07-23-2024   HQIC                          3695.112
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.1067      0.014     -7.478      0.000      -0.135      -0.079
# ma.L2         -0.2375      0.021    -11.250      0.000      -0.279      -0.196
# ma.L3          0.0531      0.027      1.946      0.052      -0.000       0.107
# sigma2         4.9840      0.059     84.216      0.000       4.868       5.100
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             39043.56
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.85   Skew:                            -1.72
# Prob(H) (two-sided):                  0.00   Kurtosis:                        36.47
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Threshold exceeded for vibr_1_X at 2024-08-27 08:00:00
# Processing: vibr_1_Y
# Tuning ARIMA parameters for vibr_1_Y...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3692.807, Time=0.71 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3745.329, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3747.282, Time=0.12 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3747.232, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3743.444, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3691.072, Time=0.67 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=3689.086, Time=0.23 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=3691.074, Time=0.31 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3723.804, Time=0.47 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=2.25 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=3687.298, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=3745.351, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=3689.282, Time=0.20 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=3689.284, Time=0.17 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=3722.223, Time=0.24 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=inf, Time=1.96 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0]
# Total fit time: 7.804 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(0, 1, 2)   Log Likelihood               -1840.649
# Date:                Sun, 17 Nov 2024   AIC                           3687.298
# Time:                        12:57:18   BIC                           3701.455
# Sample:                    07-23-2024   HQIC                          3692.728
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.0128      0.016     -0.811      0.418      -0.044       0.018
# ma.L2         -0.2783      0.023    -12.104      0.000      -0.323      -0.233
# sigma2         4.9924      0.066     75.120      0.000       4.862       5.123
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             25197.45
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.09   Skew:                            -0.68
# Prob(H) (two-sided):                  0.48   Kurtosis:                        29.99
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Threshold exceeded for vibr_1_Y at 2024-08-27 08:00:00
# Processing: vibr_1_Z
# Tuning ARIMA parameters for vibr_1_Z...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3902.843, Time=0.56 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3967.365, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3957.740, Time=0.16 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3947.657, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3965.410, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3901.397, Time=0.43 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=3900.362, Time=0.23 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=3901.634, Time=0.37 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3919.974, Time=0.37 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=3903.170, Time=0.79 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=3898.476, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=3945.729, Time=0.08 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=3899.505, Time=0.23 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=3899.743, Time=0.16 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=3918.101, Time=0.20 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=3901.279, Time=0.37 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0]
# Total fit time: 4.360 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(0, 1, 2)   Log Likelihood               -1946.238
# Date:                Sun, 17 Nov 2024   AIC                           3898.476
# Time:                        12:57:24   BIC                           3912.633
# Sample:                    07-23-2024   HQIC                          3903.906
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.1514      0.016     -9.647      0.000      -0.182      -0.121
# ma.L2         -0.2593      0.017    -14.832      0.000      -0.294      -0.225
# sigma2         6.4428      0.081     79.590      0.000       6.284       6.601
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):             36659.01
# Prob(Q):                              0.81   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.57   Skew:                            -1.90
# Prob(H) (two-sided):                  0.00   Kurtosis:                        35.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Threshold exceeded for vibr_1_Z at 2024-08-27 08:00:00
# Processing: vibr_1_noise
# Tuning ARIMA parameters for vibr_1_noise...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3480.851, Time=1.07 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3941.310, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3708.718, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3477.435, Time=0.33 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3939.311, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3479.433, Time=0.35 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=3479.434, Time=0.37 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3479.772, Time=0.71 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=3475.455, Time=0.10 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=3477.453, Time=0.15 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=3477.453, Time=0.15 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=3706.721, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=3477.791, Time=0.33 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 3.806 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(0, 1, 1)   Log Likelihood               -1735.727
# Date:                Sun, 17 Nov 2024   AIC                           3475.455
# Time:                        12:57:29   BIC                           3484.893
# Sample:                    07-23-2024   HQIC                          3479.075
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8719      0.015    -57.364      0.000      -0.902      -0.842
# sigma2         3.8689      0.035    111.795      0.000       3.801       3.937
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            121460.05
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.66   Skew:                            -4.93
# Prob(H) (two-sided):                  0.00   Kurtosis:                        61.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing: vibr_2_X
# Tuning ARIMA parameters for vibr_2_X...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3070.948, Time=1.00 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3084.139, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3085.498, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3085.514, Time=0.17 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3082.208, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3078.761, Time=0.60 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=3080.258, Time=0.69 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=3065.262, Time=1.10 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=3063.419, Time=0.67 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=3068.604, Time=0.25 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=3065.371, Time=0.94 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=3087.443, Time=0.17 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=3066.989, Time=0.27 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=3063.369, Time=1.90 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=3064.651, Time=2.01 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=3064.856, Time=2.56 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=3063.410, Time=1.74 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=3064.017, Time=1.61 sec
#  ARIMA(5,1,3)(0,0,0)[0] intercept   : AIC=3066.677, Time=1.64 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=3061.504, Time=1.23 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=3063.396, Time=0.68 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=3063.502, Time=0.55 sec
#  ARIMA(5,1,2)(0,0,0)[0]             : AIC=3062.780, Time=1.29 sec
#  ARIMA(4,1,3)(0,0,0)[0]             : AIC=3062.986, Time=1.64 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=3061.549, Time=0.33 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=3061.536, Time=0.81 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : AIC=3062.129, Time=0.83 sec
#  ARIMA(5,1,3)(0,0,0)[0]             : AIC=3064.643, Time=2.23 sec
#
# Best model:  ARIMA(4,1,2)(0,0,0)[0]
# Total fit time: 27.158 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(4, 1, 2)   Log Likelihood               -1523.752
# Date:                Sun, 17 Nov 2024   AIC                           3061.504
# Time:                        12:57:58   BIC                           3094.537
# Sample:                    07-23-2024   HQIC                          3074.173
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2933      0.255     -1.152      0.249      -0.792       0.206
# ar.L2          0.5363      0.132      4.053      0.000       0.277       0.796
# ar.L3         -0.1744      0.028     -6.312      0.000      -0.229      -0.120
# ar.L4         -0.1054      0.068     -1.554      0.120      -0.238       0.028
# ma.L1          0.3121      0.254      1.230      0.219      -0.185       0.809
# ma.L2         -0.5340      0.123     -4.344      0.000      -0.775      -0.293
# sigma2         2.3222      0.016    144.239      0.000       2.291       2.354
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            617692.61
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.34   Skew:                             3.09
# Prob(H) (two-sided):                  0.01   Kurtosis:                       136.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing: vibr_2_Y
# Tuning ARIMA parameters for vibr_2_Y...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2933.715, Time=1.00 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2964.824, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2963.917, Time=0.12 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2963.932, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2962.858, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=2946.781, Time=0.68 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=2942.571, Time=0.94 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=2930.208, Time=1.15 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=2928.514, Time=0.75 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=2947.060, Time=0.24 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=2930.192, Time=0.82 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=2965.865, Time=0.18 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=2936.300, Time=0.28 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=2932.190, Time=1.60 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=2926.596, Time=0.38 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=2940.658, Time=0.44 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=2945.102, Time=0.11 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=2928.271, Time=0.49 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=2928.287, Time=0.53 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=2963.895, Time=0.10 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=2931.790, Time=0.67 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=2934.354, Time=0.17 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=2930.269, Time=0.76 sec
#
# Best model:  ARIMA(3,1,1)(0,0,0)[0]
# Total fit time: 11.690 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(3, 1, 1)   Log Likelihood               -1458.298
# Date:                Sun, 17 Nov 2024   AIC                           2926.596
# Time:                        12:58:13   BIC                           2950.191
# Sample:                    07-23-2024   HQIC                          2935.645
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7007      0.081      8.608      0.000       0.541       0.860
# ar.L2         -0.0363      0.061     -0.595      0.552      -0.156       0.083
# ar.L3         -0.1605      0.043     -3.734      0.000      -0.245      -0.076
# ma.L1         -0.6753      0.082     -8.209      0.000      -0.837      -0.514
# sigma2         1.9825      0.017    113.881      0.000       1.948       2.017
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            246136.69
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.95   Skew:                             1.96
# Prob(H) (two-sided):                  0.00   Kurtosis:                        87.37
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing: vibr_2_Z
# Tuning ARIMA parameters for vibr_2_Z...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3465.388, Time=0.98 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3488.169, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3487.408, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3487.510, Time=0.15 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3486.181, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3475.127, Time=0.63 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=3485.605, Time=0.70 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=3457.100, Time=0.90 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=3455.997, Time=0.67 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=3463.881, Time=0.26 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=3457.048, Time=1.02 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=3489.357, Time=0.21 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=3461.174, Time=0.36 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=3459.034, Time=1.98 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=3454.030, Time=0.40 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=3483.616, Time=0.36 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=3461.899, Time=0.17 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=3455.084, Time=0.57 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=3455.135, Time=0.58 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=3487.368, Time=0.09 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=3463.420, Time=0.52 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=3459.196, Time=0.19 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=3457.069, Time=1.17 sec
#
# Best model:  ARIMA(3,1,1)(0,0,0)[0]
# Total fit time: 12.122 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(3, 1, 1)   Log Likelihood               -1722.015
# Date:                Sun, 17 Nov 2024   AIC                           3454.030
# Time:                        12:58:26   BIC                           3477.625
# Sample:                    07-23-2024   HQIC                          3463.079
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6427      0.087      7.384      0.000       0.472       0.813
# ar.L2         -0.0159      0.062     -0.257      0.797      -0.137       0.106
# ar.L3         -0.1727      0.040     -4.306      0.000      -0.251      -0.094
# ma.L1         -0.6113      0.089     -6.902      0.000      -0.785      -0.438
# sigma2         3.7486      0.029    128.739      0.000       3.692       3.806
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):            507316.21
# Prob(Q):                              0.92   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.09   Skew:                            -1.93
# Prob(H) (two-sided):                  0.00   Kurtosis:                       124.20
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing: vibr_2_noise
# Tuning ARIMA parameters for vibr_2_noise...
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.75 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=10030.703, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=8925.243, Time=0.41 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.68 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=7956.763, Time=1.00 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.97 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=7264.976, Time=0.81 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=3104.755, Time=0.35 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=1.12 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=3095.756, Time=1.52 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=inf, Time=1.19 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=3.01 sec
#  ARIMA(1,0,5)(0,0,0)[0]             : AIC=3095.043, Time=1.90 sec
#  ARIMA(0,0,5)(0,0,0)[0]             : AIC=inf, Time=2.23 sec
#  ARIMA(2,0,5)(0,0,0)[0]             : AIC=3093.249, Time=3.07 sec
#  ARIMA(3,0,5)(0,0,0)[0]             : AIC=inf, Time=3.41 sec
#  ARIMA(3,0,4)(0,0,0)[0]             : AIC=inf, Time=2.52 sec
#  ARIMA(2,0,5)(0,0,0)[0] intercept   : AIC=3080.261, Time=8.63 sec
#  ARIMA(1,0,5)(0,0,0)[0] intercept   : AIC=3079.048, Time=0.83 sec
#  ARIMA(0,0,5)(0,0,0)[0] intercept   : AIC=3077.031, Time=0.36 sec
#  ARIMA(0,0,4)(0,0,0)[0] intercept   : AIC=3075.103, Time=0.30 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=3075.664, Time=0.24 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=3077.050, Time=0.95 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=3077.745, Time=0.37 sec
#
# Best model:  ARIMA(0,0,4)(0,0,0)[0] intercept
# Total fit time: 36.705 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(0, 0, 4)   Log Likelihood               -1531.552
# Date:                Sun, 17 Nov 2024   AIC                           3075.103
# Time:                        12:59:05   BIC                           3103.425
# Sample:                    07-23-2024   HQIC                          3085.965
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    102.4752      0.064   1613.471      0.000     102.351     102.600
# ma.L1         -0.0295      0.036     -0.815      0.415      -0.100       0.041
# ma.L2         -0.0174      0.035     -0.491      0.624      -0.087       0.052
# ma.L3          0.0047      0.038      0.122      0.903      -0.070       0.079
# ma.L4          0.0519      0.033      1.587      0.113      -0.012       0.116
# sigma2         2.3563      0.104     22.601      0.000       2.152       2.561
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               190.88
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.92   Skew:                            -0.94
# Prob(H) (two-sided):                  0.46   Kurtosis:                         4.42
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing: oil_temp
# Tuning ARIMA parameters for oil_temp...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=592.670, Time=0.35 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=584.701, Time=0.22 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=586.694, Time=0.15 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=586.694, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=582.714, Time=0.10 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=588.694, Time=0.26 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 1.253 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                -290.357
# Date:                Sun, 17 Nov 2024   AIC                            582.714
# Time:                        12:59:08   BIC                            587.433
# Sample:                    07-23-2024   HQIC                           584.524
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         0.1181      0.001    211.081      0.000       0.117       0.119
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):           1584847.82
# Prob(Q):                              0.93   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.52   Skew:                           -11.66
# Prob(H) (two-sided):                  0.00   Kurtosis:                       216.06
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing: cool_temp
# Tuning ARIMA parameters for cool_temp...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=4056.307, Time=0.83 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=4070.078, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=4058.404, Time=0.12 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=4057.522, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=4068.078, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=4058.105, Time=0.85 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=4060.020, Time=0.46 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=4045.945, Time=1.15 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=4046.772, Time=0.65 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=4047.474, Time=1.77 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=4047.904, Time=1.74 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=4047.524, Time=1.12 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=4045.513, Time=0.68 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=4043.990, Time=0.27 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=4048.843, Time=0.26 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=4045.436, Time=0.48 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=4047.100, Time=2.11 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=4041.990, Time=0.15 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=4046.844, Time=0.15 sec
#  ARIMA(5,1,0)(0,0,0)[0]             : AIC=4043.436, Time=0.22 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=4043.513, Time=0.38 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=4044.772, Time=0.35 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : AIC=4045.100, Time=0.99 sec
#
# Best model:  ARIMA(4,1,0)(0,0,0)[0]
# Total fit time: 14.977 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(4, 1, 0)   Log Likelihood               -2015.995
# Date:                Sun, 17 Nov 2024   AIC                           4041.990
# Time:                        12:59:24   BIC                           4065.585
# Sample:                    07-23-2024   HQIC                          4051.039
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1226      0.025     -4.993      0.000      -0.171      -0.074
# ar.L2         -0.0367      0.077     -0.475      0.635      -0.188       0.115
# ar.L3         -0.1129      0.011    -10.198      0.000      -0.135      -0.091
# ar.L4          0.0906      0.018      5.071      0.000       0.056       0.126
# sigma2         7.6260      0.045    171.181      0.000       7.539       7.713
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):            885315.33
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.38   Skew:                           -10.91
# Prob(H) (two-sided):                  0.01   Kurtosis:                       161.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing: oil_pressure
# Tuning ARIMA parameters for oil_pressure...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=830.598, Time=1.15 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=931.409, Time=0.17 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=833.035, Time=0.24 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=827.214, Time=0.24 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=929.773, Time=0.12 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=828.712, Time=0.36 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=828.833, Time=0.35 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=829.613, Time=0.74 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=826.227, Time=0.12 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=827.670, Time=0.17 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=827.801, Time=0.15 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=831.770, Time=0.11 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=828.573, Time=0.41 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 4.348 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                -411.113
# Date:                Sun, 17 Nov 2024   AIC                            826.227
# Time:                        12:59:30   BIC                            835.665
# Sample:                    07-23-2024   HQIC                           829.846
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.3602      0.008    -46.023      0.000      -0.376      -0.345
# sigma2         0.1580      0.001    143.489      0.000       0.156       0.160
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.09   Jarque-Bera (JB):            346355.66
# Prob(Q):                              0.77   Prob(JB):                         0.00
# Heteroskedasticity (H):              10.29   Skew:                            -0.85
# Prob(H) (two-sided):                  0.00   Kurtosis:                       103.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing: total_rms_vibr
# Tuning ARIMA parameters for total_rms_vibr...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3856.583, Time=1.68 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=4161.502, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3990.099, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3853.621, Time=0.20 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=4159.507, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3854.330, Time=0.33 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=3854.215, Time=0.28 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3855.736, Time=0.54 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=3851.649, Time=0.09 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=3852.362, Time=0.15 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=3852.246, Time=0.14 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=3988.113, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=3853.766, Time=0.31 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 3.986 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(0, 1, 1)   Log Likelihood               -1923.825
# Date:                Sun, 17 Nov 2024   AIC                           3851.649
# Time:                        12:59:36   BIC                           3861.087
# Sample:                    07-23-2024   HQIC                          3855.269
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.7038      0.016    -43.303      0.000      -0.736      -0.672
# sigma2         6.0995      0.097     62.778      0.000       5.909       6.290
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.79   Jarque-Bera (JB):             11201.78
# Prob(Q):                              0.37   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.76   Skew:                            -2.90
# Prob(H) (two-sided):                  0.02   Kurtosis:                        20.06
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing: total_rms_noise
# Tuning ARIMA parameters for total_rms_noise...
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.91 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=9984.072, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=8905.037, Time=0.31 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.70 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=8067.639, Time=0.45 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=1.64 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=7454.968, Time=1.30 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=inf, Time=2.03 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=7026.548, Time=2.49 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=4382.253, Time=1.58 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=2.10 sec
#  ARIMA(1,0,5)(0,0,0)[0]             : AIC=4383.966, Time=0.63 sec
#  ARIMA(0,0,5)(0,0,0)[0]             : AIC=inf, Time=2.63 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=2.06 sec
#  ARIMA(2,0,5)(0,0,0)[0]             : AIC=inf, Time=3.18 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=4365.359, Time=2.05 sec
#  ARIMA(0,0,4)(0,0,0)[0] intercept   : AIC=4364.330, Time=0.51 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=4362.661, Time=0.43 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=4365.510, Time=0.30 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=4363.523, Time=0.58 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=4365.919, Time=1.02 sec
#
# Best model:  ARIMA(0,0,3)(0,0,0)[0] intercept
# Total fit time: 26.967 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  829
# Model:               SARIMAX(0, 0, 3)   Log Likelihood               -2176.331
# Date:                Sun, 17 Nov 2024   AIC                           4362.661
# Time:                        13:00:04   BIC                           4386.262
# Sample:                    07-23-2024   HQIC                          4371.712
#                          - 08-27-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     99.5872      0.378    263.145      0.000      98.845     100.329
# ma.L1          0.0789      0.033      2.388      0.017       0.014       0.144
# ma.L2          0.0353      0.038      0.919      0.358      -0.040       0.110
# ma.L3          0.0738      0.031      2.374      0.018       0.013       0.135
# sigma2        11.1627      0.632     17.660      0.000       9.924      12.402
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              4349.66
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.91   Skew:                            -3.13
# Prob(H) (two-sided):                  0.41   Kurtosis:                        12.32
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Threshold exceeded for total_rms_noise at 2024-08-27 08:00:00
# Maintenance required for the following parameters:
# vibr_1_X: Check and replace vibration dampeners.
# vibr_1_Y: Inspect the foundation and tighten bolts.
# vibr_1_Z: Lubricate motor and inspect bearings.
# total_rms_noise: Check for loose components or wear in mechanical parts.
